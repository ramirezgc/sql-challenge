# %%
import pandas as pd
import matplotlib.pyplot as plt
from config import username, password
# %matplotlib inline

from sqlalchemy import create_engine
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/employee_db')
connection = engine.connect()

# %% [markdown]
# # Import the SQL database into Pandas.

# %%
employees_tbl = pd.read_sql('select * from employees order by emp_no asc', connection)
employees_tbl.head()
# Out:
#    emp_no emp_title_id  birth_date first_name last_name sex   hire_date
# 0   10001        e0003  1953-09-02     Georgi   Facello   M  1986-06-26
# 1   10002        s0001  1964-06-02    Bezalel    Simmel   F  1985-11-21
# 2   10003        e0003  1959-12-03      Parto   Bamford   M  1986-08-28
# 3   10004        e0003  1954-05-01  Chirstian   Koblick   M  1986-12-01
# 4   10005        s0001  1955-01-21    Kyoichi  Maliniak   M  1989-09-12

# %%
departments_tbl = pd.read_sql('select * from departments order by dept_no asc', connection)
departments_tbl.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %%
dept_emp_tbl = pd.read_sql('select * from dept_emp order by emp_no asc', connection)
dept_emp_tbl.head()
# Out:
#    emp_no dept_no
# 0   10001    d005
# 1   10002    d007
# 2   10003    d004
# 3   10004    d004
# 4   10005    d003

# %%
dept_manager_tbl = pd.read_sql('select * from dept_manager order by dept_no asc', connection)
dept_manager_tbl.head()
# Out:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183

# %%
salaries_tbl = pd.read_sql('select * from salaries order by emp_no asc', connection)
salaries_tbl.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
titles_tbl = pd.read_sql('select * from titles order by title_id asc', connection)
titles_tbl.head()
# Out:
#   title_id               title
# 0    e0001  Assistant Engineer
# 1    e0002            Engineer
# 2    e0003     Senior Engineer
# 3    e0004    Technique Leader
# 4    m0001             Manager

# %% [markdown]
# # Create a histogram to visualize the most common salary ranges for employees.

# %%
employee_df = pd.DataFrame (employees_tbl)
employee_df.head()
# Out:
#    emp_no emp_title_id  birth_date first_name last_name sex   hire_date
# 0   10001        e0003  1953-09-02     Georgi   Facello   M  1986-06-26
# 1   10002        s0001  1964-06-02    Bezalel    Simmel   F  1985-11-21
# 2   10003        e0003  1959-12-03      Parto   Bamford   M  1986-08-28
# 3   10004        e0003  1954-05-01  Chirstian   Koblick   M  1986-12-01
# 4   10005        s0001  1955-01-21    Kyoichi  Maliniak   M  1989-09-12

# %%
salaries_df = pd.DataFrame(salaries_tbl)
salaries_df.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
merge_df = pd.merge(employee_df, salaries_df, how = "left", on="emp_no")
merge_df.head()
# Out:
#    emp_no emp_title_id  birth_date first_name last_name sex   hire_date  \
# 0   10001        e0003  1953-09-02     Georgi   Facello   M  1986-06-26
# 1   10002        s0001  1964-06-02    Bezalel    Simmel   F  1985-11-21
# 2   10003        e0003  1959-12-03      Parto   Bamford   M  1986-08-28
# 3   10004        e0003  1954-05-01  Chirstian   Koblick   M  1986-12-01
# 4   10005        s0001  1955-01-21    Kyoichi  Maliniak   M  1989-09-12
#
#    salary
# 0   60117
# 1   65828
# 2   40006
# 3   40054
# 4   78228

# %%
plt.hist(merge_df.salary)
plt.xlabel('Salary')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Create a bar chart of average salary by title.

# %%
titles_df = pd.DataFrame(titles_tbl)
titles_df.rename(columns={'title_id': 'emp_title_id'}, inplace=True)
titles_df
# Out:
#   emp_title_id               title
# 0        e0001  Assistant Engineer
# 1        e0002            Engineer
# 2        e0003     Senior Engineer
# 3        e0004    Technique Leader
# 4        m0001             Manager
# 5        s0001               Staff
# 6        s0002        Senior Staff

# %%
avg_salary_df = pd.merge(merge_df, titles_df, how = "left", on="emp_title_id")
avg_salary_df.head()
# Out:
#    emp_no emp_title_id  birth_date first_name last_name sex   hire_date  \
# 0   10001        e0003  1953-09-02     Georgi   Facello   M  1986-06-26
# 1   10002        s0001  1964-06-02    Bezalel    Simmel   F  1985-11-21
# 2   10003        e0003  1959-12-03      Parto   Bamford   M  1986-08-28
# 3   10004        e0003  1954-05-01  Chirstian   Koblick   M  1986-12-01
# 4   10005        s0001  1955-01-21    Kyoichi  Maliniak   M  1989-09-12
#
#    salary            title
# 0   60117  Senior Engineer
# 1   65828            Staff
# 2   40006  Senior Engineer
# 3   40054  Senior Engineer
# 4   78228            Staff

# %%
title_groups_df = avg_salary_df.groupby(["title"])

title_groups_mean = title_groups_df["salary"].mean()

# %%
plt.bar(title_groups_mean.index, title_groups_mean)

plt.title("Avg Salary per Title")
plt.xlabel("Title")
plt.xticks(rotation = 90)
plt.ylabel("Avg. Salary")
plt.show()
